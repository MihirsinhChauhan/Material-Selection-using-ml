# %% [markdown]
# # Project

# %% [markdown]
# ## Data Preparation

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./data/Data.csv')

# %%
data
# Out:
#        Std                                ID             Material  \
# 0     ANSI  D8894772B88F495093C43AF905AB6373       Steel SAE 1015
# 1     ANSI  05982AC66F064F9EBC709E7A4164613A       Steel SAE 1015
# 2     ANSI  356D6E63FF9A49A3AB23BF66BAC85DC3       Steel SAE 1015
# 3     ANSI  1C758F8714AC4E0D9BD8D8AE1625AECD       Steel SAE 1020
# 4     ANSI  DCE10036FC1946FC8C9108D598D116AD       Steel SAE 1020
# ...    ...                               ...                  ...
# 1547   JIS  512A80EC21EA416BA2725B38BA8096EF    Nodular cast iron
# 1548   JIS  38526441BA8741CA979DBF870D0B8A9B    Nodular cast iron
# 1549   JIS  CAC03D7EB1AA45E68EFF92A2EF4C3D9B    Nodular cast iron
# 1550   JIS  45C82A36EC644F8BB6170A99ED819B62  Malleable cast iron
# 1551   JIS  BC74F870412F4DDBADDEF1063C1C079F  Malleable cast iron
#
#      Heat treatment   Su   Sy    A5    Bhn       E      G    mu    Ro     pH  \
# 0         as-rolled  421  314  39.0  126.0  207000  79000  0.30  7860    NaN
# 1        normalized  424  324  37.0  121.0  207000  79000  0.30  7860    NaN
# 2          annealed  386  284  37.0  111.0  207000  79000  0.30  7860    NaN
# 3         as-rolled  448  331  36.0  143.0  207000  79000  0.30  7860    NaN
# 4        normalized  441  346  35.8  131.0  207000  79000  0.30  7860  550.0
# ...             ...  ...  ...   ...    ...     ...    ...   ...   ...    ...
# 1547            NaN  600  370   NaN    NaN  169000  70000  0.20  7160  480.0
# 1548            NaN  700  420   NaN    NaN  169000  70000  0.20  7160  560.0
# 1549            NaN  800  480   NaN    NaN  169000  70000  0.20  7160  600.0
# 1550            NaN  400  180   4.0    NaN  160000  64000  0.27  7160  300.0
# 1551            NaN  500  260   4.0    NaN  160000  64000  0.27  7160  370.0
#
#                      Desc     HV
# 0                     NaN    NaN
# 1                     NaN    NaN
# 2                     NaN    NaN
# 3                     NaN    NaN
# 4                     NaN    NaN
# ...                   ...    ...
# 1547    Nodular cast iron  210.0
# 1548    Nodular cast iron  230.0
# 1549    Nodular cast iron  240.0
# 1550  Malleable cast iron  220.0
# 1551  Malleable cast iron  230.0
#
# [1552 rows x 15 columns]

# %% [markdown]
# ### About Data
# The Material Dataset includes the following mechanical properties:
#
# 1. Standard (Std)
# 2. Unique Identification code for the Material (ID)
# 3. Material Name
# 4. Heat Treatment Method
# 5. Ultimate Tensile Strength (Su) in MPa
# 6. Yield Strength (Sy) in MPa
# 7. Elongation at Break or Strain (A5) as a Percentage
# 8. Brinell Hardness Number (BHN) in Microhardness Units
# 9. Elastic Modulus (E) in MPa
# 10. Shear Modulus (G) in MPa
# 11. Poisson's Ratio (mu) in Units of Length
# 12. Density (Ro) in Kg/m3
# 13. Pressure at Yield (pH) in MPa
# 14. Description of the Material (Desc)
# 15. Vickers Hardness Number (HV)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Std             1552 non-null   object
#  1   ID              1552 non-null   object
#  2   Material        1552 non-null   object
#  3   Heat treatment  802 non-null    object
#  4   Su              1552 non-null   int64
#  5   Sy              1552 non-null   object
#  6   A5              1346 non-null   float64
#  7   Bhn             463 non-null    float64
#  8   E               1552 non-null   int64
#  9   G               1552 non-null   int64
#  10  mu              1552 non-null   float64
#  11  Ro              1552 non-null   int64
#  12  pH              193 non-null    float64
#  13  Desc            981 non-null    object
#  14  HV              165 non-null    float64
# dtypes: float64(5), int64(4), object(6)
# memory usage: 182.0+ KB

# %%
# Missing Values
data.isna().sum()
# Out:
# Std                  0
# ID                   0
# Material             0
# Heat treatment     750
# Su                   0
# Sy                   0
# A5                 206
# Bhn               1089
# E                    0
# G                    0
# mu                   0
# Ro                   0
# pH                1359
# Desc               571
# HV                1387
# dtype: int64

# %%
data.drop(['ID','HV','pH','Bhn'],axis=1,inplace=True)

# %%
data.head()
# Out:
#     Std        Material Heat treatment   Su   Sy    A5       E      G   mu  \
# 0  ANSI  Steel SAE 1015      as-rolled  421  314  39.0  207000  79000  0.3
# 1  ANSI  Steel SAE 1015     normalized  424  324  37.0  207000  79000  0.3
# 2  ANSI  Steel SAE 1015       annealed  386  284  37.0  207000  79000  0.3
# 3  ANSI  Steel SAE 1020      as-rolled  448  331  36.0  207000  79000  0.3
# 4  ANSI  Steel SAE 1020     normalized  441  346  35.8  207000  79000  0.3
#
#      Ro Desc
# 0  7860  NaN
# 1  7860  NaN
# 2  7860  NaN
# 3  7860  NaN
# 4  7860  NaN

# %%
data.nunique()
# Out:
# Std                  8
# Material          1225
# Heat treatment      44
# Su                 309
# Sy                 291
# A5                  98
# E                   43
# G                   33
# mu                  11
# Ro                  35
# Desc                83
# dtype: int64

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']
categorical_features = [feature for feature in data.columns if data[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 6 numerical features : ['Su', 'A5', 'E', 'G', 'mu', 'Ro']
#
# We have 5 categorical features : ['Std', 'Material', 'Heat treatment', 'Sy', 'Desc']

# %%
print("Categories in 'Standard (Std)' variable:     ",end=" " )
print(data['Std'].unique())

print("Categories in 'Material' variable:  ",end=" ")
print(data['Material'].unique())

print("Categories in'Heat Treatment' variable:",end=" " )
print(data['Heat treatment'].unique())

print("Categories in 'Yield Strength (Sy)' variable:     ",end=" " )
print(data['Sy'].unique())

print("Categories in 'Description of material' variable:     ",end=" " )
print(data['Desc'].unique())
# Out:
# Categories in 'Standard (Std)' variable:      ['ANSI' 'ISO' 'DIN' 'BS' 'CSN' 'GOST' 'NF' 'JIS']
# Categories in 'Material' variable:   ['Steel SAE 1015' 'Steel SAE 1020' 'Steel SAE 1022' ... 'JIS SUH330'
#  'JIS SUH310' 'JIS SUH35']
# Categories in'Heat Treatment' variable: ['as-rolled' 'normalized' 'annealed' 'tempered at 400 F'
#  'tempered at 600 F' 'tempered at 800 F' '1/4-hard' '1/2-hard' '3/4-hard'
#  'Full-hard' nan 'As hot rolled' 'As extruded' 'Cast (T7)' 'Cast (T4)'
#  'Cast (F)' 'Cast (T61)' 'Cast (T77)' 'Cast (T6)' 'Cast (T62)'
#  'Cast (T51)' 'Cast (T71)' 'Cast (F or T5)' 'Cast (T5)' 'Cast (T52)'
#  'Cast (T53)' 'Wrought' 'sand casting' 'pressure die casting'
#  'heat treated' 'case-hardened' 'face hardened' 'nitro-carburized'
#  'nitro-case-hard.' 'nitrided' 'Heat-treatment nitrided steel'
#  'Cold working' 'Annealing or high tempering' 'Improved'
#  'Quenched and tempered' 'Quenching and cooling in the water'
#  'Quenching and cooling in the oil' 'Quenching and heating'
#  'Case hardening,quenching and cooling in the oil' 'Annealing']
# Categories in 'Yield Strength (Sy)' variable:      ['314' '324' '284' '331' '346' '295' '359' '317' '345' '341' '648' '414'
#  '374' '353' '593' '427' '365' '724' '483' '421' '372' '779' '586' '524'
#  '376' '979' '572' '500' '379' '827' '305' '303' '279' '316' '319' '396'
#  '938' '405' '1213' '400' '627' '558' '436' '1593' '600' '422' '758'
#  '1662' '360' '1462' '655' '417' '1641' '734' '1724' '464' '425' '862'
#  '472' '1675' '366' '484' '1407' '1517' '293' '529' '357' '1731' '531'
#  '276' '1793' '615' '412' '1689' '385' '429' '1503' '1669' '688' '386'
#  '1551' '607' '415' '1655' '579' '486' '2048' '571' '440' '517' '931'
#  '965' '255' '241' '207' '1000' '1034' '1344' '310' '1069' '448' '1896'
#  '138' '172' '538' '455' '552' '62' '248' '469' '69' '117' '110' '97' '90'
#  '83' '159' '124' '193' '290' '262' '165' '221' '145' '152' '179' '186'
#  '234' '41' '48' '76' '103' '131' '228' '269' '338' '200' '28' '34' '296'
#  '393' '352' '55' '214' '407' '283' '434' '490' '503' '462' '230' '225'
#  '380' '280 max' '240 max' '210 max' '265' '285' '325' '355' '300' '340'
#  '320' '350' '430' '460' '520' '590' '630' '660' '680' '270' '650' '770'
#  '700' '900' '1050' '390' '585' '450' '240' '190' '180' '280' '150' '250'
#  '370' '420' '480' '260' '375' '250 max' '195' '470' '275' '410' '1300'
#  '670' '665' '1270' '1180' '750' '760' '690' '850' '735' '1030' '785'
#  '550' '800' '205' '210' '580' '140' '215' '245' '1100' '510' '570' '740'
#  '685' '925' '635' '226' '373' '235' '315' '1470' '1320' '540' '1080'
#  '1210' '343' '637' '1373' '687' '588' '686' '794' '1175' '1275' '981'
#  '880' '495' '560' '175' '100' '160' '120' '130' '335' '196' '220' '330'
#  '950' '1250' '835' '1200' '885' '1400' '216' '294' '334' '392' '491'
#  '589' '441' '638' '1079' '1177' '1472' '1422' '1325' '50' '75' '105'
#  '125' '170' '225 max' '155' '1350' '620' '715' '815' '1125' '720' '810'
#  '185' '640' '177' '539']
# Categories in 'Description of material' variable:      [nan 'stainless' 'Free-cutting steel' 'Free-drawing steel'
#  'Structural steel' 'Heat-resistant steel' 'Case-hardening steel'
#  'Heat-treatment steel' 'Hardening steel' 'Stainless steel'
#  'Heat-resisting stainless steel' 'Grey cast iron' 'Nodular cast iron'
#  'Malleable cast iron' 'Structural deep-drawing steel' 'Spring steel'
#  'Nitrided steel' 'Heat-treatment hardening steel'
#  'Heat - treating weldable steel'
#  'Heat-treatment carbonitriding hardening steel'
#  'High strength weldable steel' 'Heat-treatment nitrided steel'
#  'Carbon cast steel' 'Alloy cast steel' 'Corrosion-proof cast steel'
#  'Heat-resisting cast steel' 'Aluminum bronze, wrought CuAl5'
#  'Aluminum bronze, wrought CuAl9Mn2' 'Aluminum bronze, wrought CuAl9Fe3'
#  'Aluminum bronze, wrought CuAl10Fe4Ni4' 'Tin bronze, cast CuSn5'
#  'Tin bronze, cast CuSn10' 'Tin bronze, cast CuSn12'
#  'Red bronze, cast CuSn5Zn5Pb5' 'Red bronze, cast CuSn8Zn6Pb3'
#  'Aluminum bronze, cast CuAl9Fe3' 'Aluminum bronze, cast CuAl10Fe4Ni4'
#  'Brass, wrought CuZn30' 'Brass, wrought CuZn32' 'Brass, wrought CuZn37'
#  'Brass, wrought CuZn32Pb1' 'Brass, wrought CuNi15Zn21'
#  'Brass, cast CuZn35AlFe3Mn2' 'Aluminum Alloy Wrought AlCu4Mg'
#  'Aluminum Alloy Wrought AlCu2Mg' 'Aluminum Alloy Wrought AlCu4Mg1Mn1'
#  'Aluminum Alloy Wrought AlMgSi1' 'Aluminum Alloy Wrought AlMg3'
#  'Aluminum Alloy Wrought AlMg5' 'Carbon structural steel'
#  'Carbon structural quality steel'
#  'Carbon structural quality steel, HRC59'
#  'Carbon structural quality steel, HRC58'
#  'Carbon structural quality steel, HRC35'
#  'Carbon structural quality steel, HRC42'
#  'Carbon structural quality steel, HRC48'
#  'Carbon structural quality steel, HRC56'
#  'Carbon structural quality steel, HRC45'
#  'Constructional steel of high machinability'
#  'Constructional steel of high machinability, size less than 30 mm'
#  'Constructional steel of high machinability, size greater than 30 mm'
#  'Structural alloy steel' 'Structural alloy steel, HRC59'
#  'Structural alloy steel, HRC39' 'Structural alloy steel, HRC48'
#  'Structural alloy steel, HRC50' 'Structural alloy steel, HRC43'
#  'Structural alloy steel, HRC40' 'Structural alloy steel, HRC30'
#  'Structural alloy steel, HRC46' 'Heat resistant steel'
#  'Heat resistant steel, Quenching method 1'
#  'Heat resistant steel, Quenching method 2'
#  'Corrosion-resistant, heat-resistant and high-temperature steel, tempering at 640-680 C'
#  'Corrosion-resistant, heat-resistant and high-temperature steel, tempering at 540-580 C'
#  'Corrosion-resistant, heat-resistant and high-temperature steel, quenching at 1100-1170 C, tempering at 750-800 C'
#  'Corrosion-resistant, heat-resistant and high-temperature steel, quenching at 950-1050 C, tempering at 730-780 C'
#  'Corrosion-resistant, heat-resistant and high-temperature steel'
#  'Rolled sheets and wide strips of structural quality steel. Thickness less than 100mm'
#  'Rolled sheets and wide strips of structural quality steel. Thickness from 100mm to 160mm'
#  'Rolled sheets and wide strips of structural quality steel. Thickness less than 16mm'
#  'Rolled sheets and wide strips of structural quality steel. Thickness from 16mm to 40mm'
#  'Rolled sheets and wide strips of structural quality steel. Thickness from 16mm to 100mm'
#  'Rolled sheets and wide strips of structural quality steel. Thickness from 40mm to 100mm']

# %%
print("Total Categories in 'Standard (Std)' variable:     ",end=" " )
print(len(data['Std'].unique()))

print("Total Categories in 'Material' variable:  ",end=" ")
print(len(data['Material'].unique()))

print("Total Categories in'Heat Treatment' variable:",end=" " )
print(len(data['Heat treatment'].unique()))

print("Total Categories in 'Yield Strength (Sy)' variable:     ",end=" " )
print(len(data['Sy'].unique()))

print("Total Categories in 'Description of material' variable:     ",end=" " )
print(len(data['Desc'].unique()))
# Out:
# Total Categories in 'Standard (Std)' variable:      8
# Total Categories in 'Material' variable:   1225
# Total Categories in'Heat Treatment' variable: 45
# Total Categories in 'Yield Strength (Sy)' variable:      291
# Total Categories in 'Description of material' variable:      84

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## EDA - exploratory data analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Statistical Feature

# %% [markdown]
# #### Distribution

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### Multivariate Analysis
